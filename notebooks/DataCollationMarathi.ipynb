# %% [markdown]
# # Data Collation L3Cube dataset

# %%
import pandas as pd

# %%
l3_test = pd.DataFrame(pd.read_excel('hate_bin_test.xlsx'))
l3_train = pd.DataFrame(pd.read_excel('hate_bin_train.xlsx'))
l3_val = pd.DataFrame(pd.read_excel('hate_bin_valid.xlsx'))

# %%
l3_test.head()
# Out:
#                                                 text label
# 0  @GajuNaik20 @NitinRaut_INC अबे झाटु लालबहादूर ...   HOF
# 1  @khadaksingh_ अंड नसलेल्या भक्तांना मोदी फायद्...   HOF
# 2  @BhatkhalkarA अरे माठ्या त्यांच्याकडून काहीच श...   HOF
# 3  हे हिंदूंचे सरकार नव्हे तर लांड्यांचे सरकार ! ...   HOF
# 4  @_prashantkadam कदम रडू नको तुझा मालक कोर्टात ...   HOF

# %%
l3_test['label'].value_counts()
# Out:
# HOF    1875
# NOT    1875
# Name: label, dtype: int64

# %%
l3_test['uid']  = 0

# %%
for idx in range(len(l3_test)):
    l3_test.loc[idx,'uid'] = 'l3cube_mr_test_'+str(idx)

# %%
l3_test
# Out:
#                                                    text label  \
# 0     @GajuNaik20 @NitinRaut_INC अबे झाटु लालबहादूर ...   HOF
# 1     @khadaksingh_ अंड नसलेल्या भक्तांना मोदी फायद्...   HOF
# 2     @BhatkhalkarA अरे माठ्या त्यांच्याकडून काहीच श...   HOF
# 3     हे हिंदूंचे सरकार नव्हे तर लांड्यांचे सरकार ! ...   HOF
# 4     @_prashantkadam कदम रडू नको तुझा मालक कोर्टात ...   HOF
# ...                                                 ...   ...
# 3745  TET Exam Scam : शिवकुमार चौकशीत तुकाराम सुपे य...   NOT
# 3746  अरे भडव्या जावेद अख्तर RSS, विश्व हिंदू परिषद ...   NOT
# 3747  जी-स्ट्रिंग प्रकारचा पोशाख, सूचक ठिकाणी लावलेल...   NOT
# 3748  @AdvBhushanRaut मग मतदान कश्यासाठी करता... सरक...   NOT
# 3749  @raam_bhatte @BadeVilas ते दोन्ही डगरी वर पाय ...   NOT
#
#                       uid
# 0        l3cube_mr_test_0
# 1        l3cube_mr_test_1
# 2        l3cube_mr_test_2
# 3        l3cube_mr_test_3
# 4        l3cube_mr_test_4
# ...                   ...
# 3745  l3cube_mr_test_3745
# ...

# %%
l3_test.label.replace('HOF', 1,inplace=True)
l3_test.label.replace('NOT', 0,inplace=True)

# %%
l3_test
# Out:
#                                                    text  label  \
# 0     @GajuNaik20 @NitinRaut_INC अबे झाटु लालबहादूर ...      1
# 1     @khadaksingh_ अंड नसलेल्या भक्तांना मोदी फायद्...      1
# 2     @BhatkhalkarA अरे माठ्या त्यांच्याकडून काहीच श...      1
# 3     हे हिंदूंचे सरकार नव्हे तर लांड्यांचे सरकार ! ...      1
# 4     @_prashantkadam कदम रडू नको तुझा मालक कोर्टात ...      1
# ...                                                 ...    ...
# 3745  TET Exam Scam : शिवकुमार चौकशीत तुकाराम सुपे य...      0
# 3746  अरे भडव्या जावेद अख्तर RSS, विश्व हिंदू परिषद ...      0
# 3747  जी-स्ट्रिंग प्रकारचा पोशाख, सूचक ठिकाणी लावलेल...      0
# 3748  @AdvBhushanRaut मग मतदान कश्यासाठी करता... सरक...      0
# 3749  @raam_bhatte @BadeVilas ते दोन्ही डगरी वर पाय ...      0
#
#                       uid
# 0        l3cube_mr_test_0
# 1        l3cube_mr_test_1
# 2        l3cube_mr_test_2
# 3        l3cube_mr_test_3
# 4        l3cube_mr_test_4
# ...                   ...
# ...

# %%
l3_test.rename(columns = {'label':'label_yn'}, inplace = True)

# %%
first_column = l3_test.pop('uid')
  

l3_test.insert(0, 'uid', first_column)

# %%
l3_test
# Out:
#                       uid                                               text  \
# 0        l3cube_mr_test_0  @GajuNaik20 @NitinRaut_INC अबे झाटु लालबहादूर ...
# 1        l3cube_mr_test_1  @khadaksingh_ अंड नसलेल्या भक्तांना मोदी फायद्...
# 2        l3cube_mr_test_2  @BhatkhalkarA अरे माठ्या त्यांच्याकडून काहीच श...
# 3        l3cube_mr_test_3  हे हिंदूंचे सरकार नव्हे तर लांड्यांचे सरकार ! ...
# 4        l3cube_mr_test_4  @_prashantkadam कदम रडू नको तुझा मालक कोर्टात ...
# ...                   ...                                                ...
# 3745  l3cube_mr_test_3745  TET Exam Scam : शिवकुमार चौकशीत तुकाराम सुपे य...
# 3746  l3cube_mr_test_3746  अरे भडव्या जावेद अख्तर RSS, विश्व हिंदू परिषद ...
# 3747  l3cube_mr_test_3747  जी-स्ट्रिंग प्रकारचा पोशाख, सूचक ठिकाणी लावलेल...
# 3748  l3cube_mr_test_3748  @AdvBhushanRaut मग मतदान कश्यासाठी करता... सरक...
# 3749  l3cube_mr_test_3749  @raam_bhatte @BadeVilas ते दोन्ही डगरी वर पाय ...
#
#       label_yn
# 0            1
# ...

# %%
l3_test.label_yn.value_counts()
# Out:
# 1    1875
# 0    1875
# Name: label_yn, dtype: int64

# %%
l3_test.to_csv('l3cube_mr_test.csv', header=True, index=False)

# %%
l3_test.loc[83]
# Out:
# uid                                         l3cube_mr_test_83
# text        मुंबईतील गटारहूंगे @ShelarAshish &amp; @KiritS...
# label_yn                                                    1
# Name: 83, dtype: object

# %%
l3_test = pd.DataFrame(pd.read_csv('l3cube_mr_test.csv'))

# %%
l3_train.head()
# Out:
#                                                 text label
# 0           @Rohitkh76543 @PawarSpeaks तू कोण लवड्या   HOF
# 1  @mohitbharatiya_ लवड्या अगोदरच रडायला लागलास तू 😂   HOF
# 2  कुठं तरी आईघाल जा लवड्या, काही केला तरी तुझी क...   HOF
# 3  तेलतुंबड्या सारख्या च्या नाजायज पैदाइशीचा कुत्...   HOF
# 4  @TV9Marathi @BJP4Maharashtra नेता...???मादरचोद...   HOF

# %%
l3_train['label'].value_counts()
# Out:
# HOF    15000
# NOT    15000
# Name: label, dtype: int64

# %%
l3_train['uid']  = 0

# %%
for idx in range(len(l3_train)):
    l3_train.loc[idx,'uid'] = 'l3cube_mr_train_'+str(idx)

# %%
l3_train
# Out:
#                                                     text label  \
# 0               @Rohitkh76543 @PawarSpeaks तू कोण लवड्या   HOF
# 1      @mohitbharatiya_ लवड्या अगोदरच रडायला लागलास तू 😂   HOF
# 2      कुठं तरी आईघाल जा लवड्या, काही केला तरी तुझी क...   HOF
# 3      तेलतुंबड्या सारख्या च्या नाजायज पैदाइशीचा कुत्...   HOF
# 4      @TV9Marathi @BJP4Maharashtra नेता...???मादरचोद...   HOF
# ...                                                  ...   ...
# 29995  @abpmajhatv आज कल्याण, मिलन, टाइम बाजार सट्टा ...   NOT
# 29996  मदर तेरेसा यांनी समाजातील उपेक्षित, असहाय्य व्...   NOT
# 29997  मा. ना. राजेशजी टोपे, आरोग्यमंत्री, महाराष्ट्र...   NOT
# 29998  @tanmay_sabnis @BhatkhalkarA मुघलांचे 100 पिढ्...   NOT
# 29999  लग्नसमारंभात गेल्यानंतर जेवणाच्या पंगतीत वाढपी...   NOT
#
#                          uid
# 0          l3cube_mr_train_0
# 1          l3cube_mr_train_1
# 2          l3cube_mr_train_2
# 3          l3cube_mr_train_3
# 4          l3cube_mr_train_4
# ...

# %%
l3_train.label.replace('HOF', 1,inplace=True)
l3_train.label.replace('NOT', 0,inplace=True)

# %%
l3_train
# Out:
#                                                     text  label  \
# 0               @Rohitkh76543 @PawarSpeaks तू कोण लवड्या      1
# 1      @mohitbharatiya_ लवड्या अगोदरच रडायला लागलास तू 😂      1
# 2      कुठं तरी आईघाल जा लवड्या, काही केला तरी तुझी क...      1
# 3      तेलतुंबड्या सारख्या च्या नाजायज पैदाइशीचा कुत्...      1
# 4      @TV9Marathi @BJP4Maharashtra नेता...???मादरचोद...      1
# ...                                                  ...    ...
# 29995  @abpmajhatv आज कल्याण, मिलन, टाइम बाजार सट्टा ...      0
# 29996  मदर तेरेसा यांनी समाजातील उपेक्षित, असहाय्य व्...      0
# 29997  मा. ना. राजेशजी टोपे, आरोग्यमंत्री, महाराष्ट्र...      0
# 29998  @tanmay_sabnis @BhatkhalkarA मुघलांचे 100 पिढ्...      0
# 29999  लग्नसमारंभात गेल्यानंतर जेवणाच्या पंगतीत वाढपी...      0
#
#                          uid
# 0          l3cube_mr_train_0
# 1          l3cube_mr_train_1
# 2          l3cube_mr_train_2
# 3          l3cube_mr_train_3
# 4          l3cube_mr_train_4
# ...

# %%
l3_train.rename(columns = {'label':'label_yn'}, inplace = True)

# %%
first_column = l3_train.pop('uid')
  

l3_train.insert(0, 'uid', first_column)

# %%
l3_train
# Out:
#                          uid  \
# 0          l3cube_mr_train_0
# 1          l3cube_mr_train_1
# 2          l3cube_mr_train_2
# 3          l3cube_mr_train_3
# 4          l3cube_mr_train_4
# ...                      ...
# 29995  l3cube_mr_train_29995
# 29996  l3cube_mr_train_29996
# 29997  l3cube_mr_train_29997
# 29998  l3cube_mr_train_29998
# 29999  l3cube_mr_train_29999
#
#                                                     text  label_yn
# 0               @Rohitkh76543 @PawarSpeaks तू कोण लवड्या         1
# 1      @mohitbharatiya_ लवड्या अगोदरच रडायला लागलास तू 😂         1
# 2      कुठं तरी आईघाल जा लवड्या, काही केला तरी तुझी क...         1
# 3      तेलतुंबड्या सारख्या च्या नाजायज पैदाइशीचा कुत्...         1
# 4      @TV9Marathi @BJP4Maharashtra नेता...???मादरचोद...         1
# ...                                                  ...       ...
# 29995  @abpmajhatv आज कल्याण, मिलन, टाइम बाजार सट्टा ...         0
# 29996  मदर तेरेसा यांनी समाजातील उपेक्षित, असहाय्य व्...         0
# ...

# %%
l3_train.label_yn.value_counts()
# Out:
# 1    15000
# 0    15000
# Name: label_yn, dtype: int64

# %%
l3_train.to_csv('l3cube_mr_train.csv', header=True, index=False)

# %%
l3_val.head()
# Out:
#                                                 text label
# 0  @BhatkhalkarA तुझी लायकी काय तू बोलतो कोणा बदल...   HOF
# 1  हिंदू धर्माबद्दल अपशब्द उगारणारा मोकाट आन उस्म...   HOF
# 2  @abpmajhatv खांडक्या,विघानसभेत अजितदादा काय बो...   HOF
# 3  @ashish_jadhao @AUThackeray सरकार मधला बावळट स...   HOF
# 4  ब्राह्मणवाद इतका वाईट, निच, आणि कपटी आहे की स्...   HOF

# %%
l3_val['label'].value_counts()
# Out:
# HOF    1875
# NOT    1875
# Name: label, dtype: int64

# %%
l3_val['uid']  = 0

# %%
for idx in range(len(l3_val)):
    l3_val.loc[idx,'uid'] = 'l3cube_mr_val_'+str(idx)

# %%
l3_val
# Out:
#                                                    text label  \
# 0     @BhatkhalkarA तुझी लायकी काय तू बोलतो कोणा बदल...   HOF
# 1     हिंदू धर्माबद्दल अपशब्द उगारणारा मोकाट आन उस्म...   HOF
# 2     @abpmajhatv खांडक्या,विघानसभेत अजितदादा काय बो...   HOF
# 3     @ashish_jadhao @AUThackeray सरकार मधला बावळट स...   HOF
# 4     ब्राह्मणवाद इतका वाईट, निच, आणि कपटी आहे की स्...   HOF
# ...                                                 ...   ...
# 3745  मुंबई हे आंतरराष्ट्रीय दर्जाचे, वेगवान शहर बना...   NOT
# 3746  शब्द - झामल झामल झामल झामल (adverb) - actually...   NOT
# 3747  आज बोरीवली येथील स्वामी विवेकानंद वाचलनालय आणि...   NOT
# 3748  मानवी मेंदूची क्षमता मर्यादित असते. तो एकाच वे...   NOT
# 3749  @aniruddha3365 अष्टावक्र त्यांचे सदगुरू   अष्ट...   NOT
#
#                      uid
# 0        l3cube_mr_val_0
# 1        l3cube_mr_val_1
# 2        l3cube_mr_val_2
# 3        l3cube_mr_val_3
# 4        l3cube_mr_val_4
# ...                  ...
# 3745  l3cube_mr_val_3745
# ...

# %%
l3_val.label.replace('HOF', 1,inplace=True)
l3_val.label.replace('NOT', 0,inplace=True)

# %%
l3_val
# Out:
#                                                    text  label  \
# 0     @BhatkhalkarA तुझी लायकी काय तू बोलतो कोणा बदल...      1
# 1     हिंदू धर्माबद्दल अपशब्द उगारणारा मोकाट आन उस्म...      1
# 2     @abpmajhatv खांडक्या,विघानसभेत अजितदादा काय बो...      1
# 3     @ashish_jadhao @AUThackeray सरकार मधला बावळट स...      1
# 4     ब्राह्मणवाद इतका वाईट, निच, आणि कपटी आहे की स्...      1
# ...                                                 ...    ...
# 3745  मुंबई हे आंतरराष्ट्रीय दर्जाचे, वेगवान शहर बना...      0
# 3746  शब्द - झामल झामल झामल झामल (adverb) - actually...      0
# 3747  आज बोरीवली येथील स्वामी विवेकानंद वाचलनालय आणि...      0
# 3748  मानवी मेंदूची क्षमता मर्यादित असते. तो एकाच वे...      0
# 3749  @aniruddha3365 अष्टावक्र त्यांचे सदगुरू   अष्ट...      0
#
#                      uid
# 0        l3cube_mr_val_0
# 1        l3cube_mr_val_1
# 2        l3cube_mr_val_2
# 3        l3cube_mr_val_3
# 4        l3cube_mr_val_4
# ...                  ...
# ...

# %%
l3_val.rename(columns = {'label':'label_yn'}, inplace = True)

# %%
first_column = l3_val.pop('uid')

l3_val.insert(0, 'uid', first_column)

# %%
l3_val
# Out:
#                      uid                                               text  \
# 0        l3cube_mr_val_0  @BhatkhalkarA तुझी लायकी काय तू बोलतो कोणा बदल...
# 1        l3cube_mr_val_1  हिंदू धर्माबद्दल अपशब्द उगारणारा मोकाट आन उस्म...
# 2        l3cube_mr_val_2  @abpmajhatv खांडक्या,विघानसभेत अजितदादा काय बो...
# 3        l3cube_mr_val_3  @ashish_jadhao @AUThackeray सरकार मधला बावळट स...
# 4        l3cube_mr_val_4  ब्राह्मणवाद इतका वाईट, निच, आणि कपटी आहे की स्...
# ...                  ...                                                ...
# 3745  l3cube_mr_val_3745  मुंबई हे आंतरराष्ट्रीय दर्जाचे, वेगवान शहर बना...
# 3746  l3cube_mr_val_3746  शब्द - झामल झामल झामल झामल (adverb) - actually...
# 3747  l3cube_mr_val_3747  आज बोरीवली येथील स्वामी विवेकानंद वाचलनालय आणि...
# 3748  l3cube_mr_val_3748  मानवी मेंदूची क्षमता मर्यादित असते. तो एकाच वे...
# 3749  l3cube_mr_val_3749  @aniruddha3365 अष्टावक्र त्यांचे सदगुरू   अष्ट...
#
#       label_yn
# 0            1
# 1            1
# ...

# %%
l3_val.label_yn.value_counts()
# Out:
# 1    1875
# 0    1875
# Name: label_yn, dtype: int64

# %%
l3_val.to_csv('l3cube_mr_val.csv', header=True, index=False)

# %%
l3_test = pd.DataFrame(pd.read_csv('l3cube_mr_test.csv'))
l3_train = pd.DataFrame(pd.read_csv('l3cube_mr_train.csv'))
l3_val = pd.DataFrame(pd.read_csv('l3cube_mr_val.csv'))

# %%
lst = [l3_train, l3_test, l3_val]  
l3cube= pd.concat(lst)

# %%
l3cube.head()
# Out:
#                  uid                                               text  \
# 0  l3cube_mr_train_0           @Rohitkh76543 @PawarSpeaks तू कोण लवड्या
# 1  l3cube_mr_train_1  @mohitbharatiya_ लवड्या अगोदरच रडायला लागलास तू 😂
# 2  l3cube_mr_train_2  कुठं तरी आईघाल जा लवड्या, काही केला तरी तुझी क...
# 3  l3cube_mr_train_3  तेलतुंबड्या सारख्या च्या नाजायज पैदाइशीचा कुत्...
# 4  l3cube_mr_train_4  @TV9Marathi @BJP4Maharashtra नेता...???मादरचोद...
#
#    label_yn
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %%
l3cube.shape
# Out:
# (37500, 3)

# %%
l3cube.head()
# Out:
#                  uid                                               text  \
# 0  l3cube_mr_train_0           @Rohitkh76543 @PawarSpeaks तू कोण लवड्या
# 1  l3cube_mr_train_1  @mohitbharatiya_ लवड्या अगोदरच रडायला लागलास तू 😂
# 2  l3cube_mr_train_2  कुठं तरी आईघाल जा लवड्या, काही केला तरी तुझी क...
# 3  l3cube_mr_train_3  तेलतुंबड्या सारख्या च्या नाजायज पैदाइशीचा कुत्...
# 4  l3cube_mr_train_4  @TV9Marathi @BJP4Maharashtra नेता...???मादरचोद...
#
#    label_yn
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %%
for idx in range(len(l3cube)):
    l3cube.loc[idx,'uid'] = 'l3cube_mr_'+str(idx)

# %%
l3cube.head()
# Out:
#            uid                                               text  label_yn
# 0  l3cube_mr_0           @Rohitkh76543 @PawarSpeaks तू कोण लवड्या       1.0
# 1  l3cube_mr_1  @mohitbharatiya_ लवड्या अगोदरच रडायला लागलास तू 😂       1.0
# 2  l3cube_mr_2  कुठं तरी आईघाल जा लवड्या, काही केला तरी तुझी क...       1.0
# 3  l3cube_mr_3  तेलतुंबड्या सारख्या च्या नाजायज पैदाइशीचा कुत्...       1.0
# 4  l3cube_mr_4  @TV9Marathi @BJP4Maharashtra नेता...???मादरचोद...       1.0

# %%
l3cube.to_csv('l3cube_mr.csv', header=True, index=False)

# %% [markdown]
# # DeepOffense dataset collation

# %%
deep_test.head()
# Out:
#                                                tweet  subtask_a subtask_b  \
# 0    मुद्दामहून थुकत बसला  ते पण दोस्तांना बोलवून...  Offensive       TIN
# 1   भेंचोद  जेव्हा कोरोना कोरोना चालू होतं तेव्हा...  Offensive       TIN
# 2   तुम्ही काय गोट्या खेळायला राज्य सरकार मध्ये आ...  Offensive       TIN
# 3   शिवसेनेने निवडणुकीत स्वतंत्र बाणा ठेवावा.दळभद...  Offensive       TIN
# 4   माझा हंटर चांगलाच घुसलाय आईच्या पुच्चीत तुझ्य...  Offensive       TIN
#
#   subtask_c
# 0       IND
# 1       OTH
# 2       OTH
# 3       GRP
# 4       IND

# %%
deep_test_new = pd.DataFrame(pd.read_csv('test_data_offensive_language_marathi_updated.csv'))
deep_train_new = pd.DataFrame(pd.read_csv('test_data_offensive_language_marathi_updated.csv'))

# %%
deep_test_new.head()
# Out:
#                                                Tweet          Class
# 0   माणसाची सर्वात मोठी समस्या   इतिहासाचे दाखले ...  not offensive
# 1    मुद्दामहून थुकत बसला  ते पण दोस्तांना बोलवून...      offensive
# 2   तुझे नोटिफिकेशन ऑन केलेत परंतु नाव दिसलं का श...  not offensive
# 3   पांडुरंग हरी  वासुदेव हरी  तु तुझ्या घरी  मी ...  not offensive
# 4   भेंचोद  जेव्हा कोरोना कोरोना चालू होतं तेव्हा...      offensive

# %%
deep_test_new.rename(columns = {'Class':'label_yn','Tweet':'text'}, inplace = True)
deep_train_new.rename(columns = {'Class':'label_yn','Tweet':'text'}, inplace = True)

# %%
for idx in range(len(deep_test_new)):
    deep_test_new.loc[idx,'uid'] = 'deepoffense_mr_t1_test_'+str(idx)

# %%
for idx in range(len(deep_train_new)):
    deep_train_new.loc[idx,'uid'] = 'deepoffense_mr_t1_train_'+str(idx)

# %%
deep_train_new.head()
# Out:
#                                                 text       label_yn  \
# 0   माणसाची सर्वात मोठी समस्या   इतिहासाचे दाखले ...  not offensive
# 1    मुद्दामहून थुकत बसला  ते पण दोस्तांना बोलवून...      offensive
# 2   तुझे नोटिफिकेशन ऑन केलेत परंतु नाव दिसलं का श...  not offensive
# 3   पांडुरंग हरी  वासुदेव हरी  तु तुझ्या घरी  मी ...  not offensive
# 4   भेंचोद  जेव्हा कोरोना कोरोना चालू होतं तेव्हा...      offensive
#
#                          uid
# 0  deepoffense_mr_t1_train_0
# 1  deepoffense_mr_t1_train_1
# 2  deepoffense_mr_t1_train_2
# 3  deepoffense_mr_t1_train_3
# 4  deepoffense_mr_t1_train_4

# %%
deep_test_new.head()
# Out:
#                                                 text       label_yn  \
# 0   माणसाची सर्वात मोठी समस्या   इतिहासाचे दाखले ...  not offensive
# 1    मुद्दामहून थुकत बसला  ते पण दोस्तांना बोलवून...      offensive
# 2   तुझे नोटिफिकेशन ऑन केलेत परंतु नाव दिसलं का श...  not offensive
# 3   पांडुरंग हरी  वासुदेव हरी  तु तुझ्या घरी  मी ...  not offensive
# 4   भेंचोद  जेव्हा कोरोना कोरोना चालू होतं तेव्हा...      offensive
#
#                         uid
# 0  deepoffense_mr_t1_test_0
# 1  deepoffense_mr_t1_test_1
# 2  deepoffense_mr_t1_test_2
# 3  deepoffense_mr_t1_test_3
# 4  deepoffense_mr_t1_test_4

# %%
deep_test_new.label_yn.replace('offensive', 1,inplace=True)
deep_test_new.label_yn.replace('not offensive', 0,inplace=True)
deep_train_new.label_yn.replace('offensive', 1,inplace=True)
deep_train_new.label_yn.replace('not offensive', 0,inplace=True)

# %%
first_column = deep_train_new.pop('uid')

deep_train_new.insert(0, 'uid', first_column)

# %%
first_column = deep_test_new.pop('uid')
  

deep_test_new.insert(0, 'uid', first_column)

# %%
deep_test_new.head()
# Out:
#                         uid  \
# 0  deepoffense_mr_t1_test_0
# 1  deepoffense_mr_t1_test_1
# 2  deepoffense_mr_t1_test_2
# 3  deepoffense_mr_t1_test_3
# 4  deepoffense_mr_t1_test_4
#
#                                                 text  label_yn
# 0   माणसाची सर्वात मोठी समस्या   इतिहासाचे दाखले ...         0
# 1    मुद्दामहून थुकत बसला  ते पण दोस्तांना बोलवून...         1
# 2   तुझे नोटिफिकेशन ऑन केलेत परंतु नाव दिसलं का श...         0
# 3   पांडुरंग हरी  वासुदेव हरी  तु तुझ्या घरी  मी ...         0
# 4   भेंचोद  जेव्हा कोरोना कोरोना चालू होतं तेव्हा...         1

# %%
deep_train_new.head()
# Out:
#                          uid  \
# 0  deepoffense_mr_t1_train_0
# 1  deepoffense_mr_t1_train_1
# 2  deepoffense_mr_t1_train_2
# 3  deepoffense_mr_t1_train_3
# 4  deepoffense_mr_t1_train_4
#
#                                                 text  label_yn
# 0   माणसाची सर्वात मोठी समस्या   इतिहासाचे दाखले ...         0
# 1    मुद्दामहून थुकत बसला  ते पण दोस्तांना बोलवून...         1
# 2   तुझे नोटिफिकेशन ऑन केलेत परंतु नाव दिसलं का श...         0
# 3   पांडुरंग हरी  वासुदेव हरी  तु तुझ्या घरी  मी ...         0
# 4   भेंचोद  जेव्हा कोरोना कोरोना चालू होतं तेव्हा...         1

# %%
deep_train_new.to_csv('deepoffense_mr_t1_train.csv', header=True, index=False)
deep_test_new.to_csv('deepoffense_mr_t1_test.csv', header=True, index=False)

# %%
deep_train_new = pd.DataFrame(pd.read_csv('deepoffense_mr_t1_train.csv'))
deep_test_new = pd.DataFrame(pd.read_csv('deepoffense_mr_t1_test.csv'))

# %%
lst = [deep_train_new, deep_test_new,]  # List of your dataframes
deep= pd.concat(lst)

# %%
deep.head()
# Out:
#                          uid  \
# 0  deepoffense_mr_t1_train_0
# 1  deepoffense_mr_t1_train_1
# 2  deepoffense_mr_t1_train_2
# 3  deepoffense_mr_t1_train_3
# 4  deepoffense_mr_t1_train_4
#
#                                                 text  label_yn
# 0   माणसाची सर्वात मोठी समस्या   इतिहासाचे दाखले ...         0
# 1    मुद्दामहून थुकत बसला  ते पण दोस्तांना बोलवून...         1
# 2   तुझे नोटिफिकेशन ऑन केलेत परंतु नाव दिसलं का श...         0
# 3   पांडुरंग हरी  वासुदेव हरी  तु तुझ्या घरी  मी ...         0
# 4   भेंचोद  जेव्हा कोरोना कोरोना चालू होतं तेव्हा...         1

# %%
deep.shape
# Out:
# (1250, 3)

# %%
deep_train_new.shape
# Out:
# (625, 3)

# %%
deep.to_csv('deepoffense_mr_t1.csv', header=True, index=False)

# %%
deep_test = pd.DataFrame(pd.read_csv('MOLD_Testing.tsv',sep='\t'))
deep_train = pd.DataFrame(pd.read_csv('MOLD_Training.tsv',sep='\t'))

# %%
deep_test
# Out:
#                                                  tweet      subtask_a  \
# 0      मुद्दामहून थुकत बसला  ते पण दोस्तांना बोलवून...      Offensive
# 1     भेंचोद  जेव्हा कोरोना कोरोना चालू होतं तेव्हा...      Offensive
# 2     तुम्ही काय गोट्या खेळायला राज्य सरकार मध्ये आ...      Offensive
# 3     शिवसेनेने निवडणुकीत स्वतंत्र बाणा ठेवावा.दळभद...      Offensive
# 4     माझा हंटर चांगलाच घुसलाय आईच्या पुच्चीत तुझ्य...      Offensive
# ..                                                 ...            ...
# 621   मिट्रो कोथरुड मध्ये टेस्टिंग सेंटर कुठे आहे ए...  not offensive
# 622   लग्न  मुंज किंवा आणखी कोणते कार्या साठी 50 50...  not offensive
# 623   भारतातील सहिष्णूतेच पाहिलं कारण आहे भारतातील ...  not offensive
# 624   माझं मत एवढंच आहे की  तुम्ही तुमचं चॅनेल मोफत...  not offensive
# 625   फक्त प्रेम कविता टाकून मिरवणाऱ्या ठोंब्यांनी ...  not offensive
#
#     subtask_b subtask_c
# 0         TIN       IND
# 1         TIN       OTH
# 2         TIN       OTH
# 3         TIN       GRP
# ...

# %%
deep_test.rename(columns = {'subtask_a':'label_yn','tweet':'text'}, inplace = True)
deep_train.rename(columns = {'subtask_a':'label_yn','tweet':'text'}, inplace = True)

# %%
for idx in range(len(deep_test)):
    deep_test.loc[idx,'uid'] = 'deepoffense_mr_t2_test_'+str(idx)

# %%
for idx in range(len(deep_train)):
    deep_train.loc[idx,'uid'] = 'deepoffense_mr_t2_train_'+str(idx)

# %%
deep_train.head()
# Out:
#                                                 text   label_yn subtask_b  \
# 0  राम कदम वागण्यात नाही तर बोलण्यात चुकला  बीजेप...  Offensive       TIN
# 1  हीच का तुमची शिवसेने चि शिकवण... आपली आई म्हणज...  Offensive       TIN
# 2  हे वाचा गाढवांनो. आणि हे ही सांगा की तुमच्या म...  Offensive       TIN
# 3         भक्त आंधळे असतात. मूर्खा ना काही कळत नाही.  Offensive       TIN
# 4  १९६६ साली छत्रपती शिवाजी महाराज या जागतिक दर्ज...  Offensive       TIN
#
#   subtask_c                        uid
# 0       GRP  deepoffense_mr_t2_train_0
# 1       GRP  deepoffense_mr_t2_train_1
# 2       GRP  deepoffense_mr_t2_train_2
# 3       GRP  deepoffense_mr_t2_train_3
# 4       GRP  deepoffense_mr_t2_train_4

# %%
deep_test.head()
# Out:
#                                                 text   label_yn subtask_b  \
# 0    मुद्दामहून थुकत बसला  ते पण दोस्तांना बोलवून...  Offensive       TIN
# 1   भेंचोद  जेव्हा कोरोना कोरोना चालू होतं तेव्हा...  Offensive       TIN
# 2   तुम्ही काय गोट्या खेळायला राज्य सरकार मध्ये आ...  Offensive       TIN
# 3   शिवसेनेने निवडणुकीत स्वतंत्र बाणा ठेवावा.दळभद...  Offensive       TIN
# 4   माझा हंटर चांगलाच घुसलाय आईच्या पुच्चीत तुझ्य...  Offensive       TIN
#
#   subtask_c                       uid
# 0       IND  deepoffense_mr_t2_test_0
# 1       OTH  deepoffense_mr_t2_test_1
# 2       OTH  deepoffense_mr_t2_test_2
# 3       GRP  deepoffense_mr_t2_test_3
# 4       IND  deepoffense_mr_t2_test_4

# %%
deep_test.label_yn.value_counts()
# Out:
# not offensive    420
# Offensive        206
# Name: label_yn, dtype: int64

# %%
deep_test.label_yn.replace('Offensive', 1,inplace=True)
deep_test.label_yn.replace('not offensive', 0,inplace=True)
deep_train.label_yn.replace('Offensive', 1,inplace=True)
deep_train.label_yn.replace('not offensive', 0,inplace=True)

# %%
first_column = deep_train.pop('uid')
  

deep_train.insert(0, 'uid', first_column)

# %%
first_column = deep_test.pop('uid')
deep_test.insert(0, 'uid', first_column)

# %%
deep_test.head()
# Out:
#                         uid  \
# 0  deepoffense_mr_t2_test_0
# 1  deepoffense_mr_t2_test_1
# 2  deepoffense_mr_t2_test_2
# 3  deepoffense_mr_t2_test_3
# 4  deepoffense_mr_t2_test_4
#
#                                                 text  label_yn subtask_b  \
# 0    मुद्दामहून थुकत बसला  ते पण दोस्तांना बोलवून...         1       TIN
# 1   भेंचोद  जेव्हा कोरोना कोरोना चालू होतं तेव्हा...         1       TIN
# 2   तुम्ही काय गोट्या खेळायला राज्य सरकार मध्ये आ...         1       TIN
# 3   शिवसेनेने निवडणुकीत स्वतंत्र बाणा ठेवावा.दळभद...         1       TIN
# 4   माझा हंटर चांगलाच घुसलाय आईच्या पुच्चीत तुझ्य...         1       TIN
#
#   subtask_c
# 0       IND
# 1       OTH
# 2       OTH
# 3       GRP
# 4       IND

# %%
deep_test = deep_test[['uid','text','label_yn']]
deep_train = deep_train[['uid','text','label_yn']]

# %%
deep_test
# Out:
#                             uid  \
# 0      deepoffense_mr_t2_test_0
# 1      deepoffense_mr_t2_test_1
# 2      deepoffense_mr_t2_test_2
# 3      deepoffense_mr_t2_test_3
# 4      deepoffense_mr_t2_test_4
# ..                          ...
# 621  deepoffense_mr_t2_test_621
# 622  deepoffense_mr_t2_test_622
# 623  deepoffense_mr_t2_test_623
# 624  deepoffense_mr_t2_test_624
# 625  deepoffense_mr_t2_test_625
#
#                                                   text  label_yn
# 0      मुद्दामहून थुकत बसला  ते पण दोस्तांना बोलवून...         1
# 1     भेंचोद  जेव्हा कोरोना कोरोना चालू होतं तेव्हा...         1
# 2     तुम्ही काय गोट्या खेळायला राज्य सरकार मध्ये आ...         1
# 3     शिवसेनेने निवडणुकीत स्वतंत्र बाणा ठेवावा.दळभद...         1
# 4     माझा हंटर चांगलाच घुसलाय आईच्या पुच्चीत तुझ्य...         1
# ..                                                 ...       ...
# 621   मिट्रो कोथरुड मध्ये टेस्टिंग सेंटर कुठे आहे ए...         0
# ...

# %%
deep_train
# Out:
#                                uid  \
# 0        deepoffense_mr_t2_train_0
# 1        deepoffense_mr_t2_train_1
# 2        deepoffense_mr_t2_train_2
# 3        deepoffense_mr_t2_train_3
# 4        deepoffense_mr_t2_train_4
# ...                            ...
# 2494  deepoffense_mr_t2_train_2494
# 2495  deepoffense_mr_t2_train_2495
# 2496  deepoffense_mr_t2_train_2496
# 2497  deepoffense_mr_t2_train_2497
# 2498  deepoffense_mr_t2_train_2498
#
#                                                    text  label_yn
# 0     राम कदम वागण्यात नाही तर बोलण्यात चुकला  बीजेप...         1
# 1     हीच का तुमची शिवसेने चि शिकवण... आपली आई म्हणज...         1
# 2     हे वाचा गाढवांनो. आणि हे ही सांगा की तुमच्या म...         1
# 3            भक्त आंधळे असतात. मूर्खा ना काही कळत नाही.         1
# 4     १९६६ साली छत्रपती शिवाजी महाराज या जागतिक दर्ज...         1
# ...                                                 ...       ...
# 2494   पण बरेच जण जन्मजात मंद   मूर्ख आणि अंधभक्त अस...         1
# ...

# %%
deep_train.to_csv('deepoffense_mr_t2_train.csv', header=True, index=False)
deep_test.to_csv('deepoffense_mr_t2_test.csv', header=True, index=False)

# %%
deep_train= pd.DataFrame(pd.read_csv('deepoffense_mr_t2_train.csv'))
deep_test = pd.DataFrame(pd.read_csv('deepoffense_mr_t2_test.csv'))

# %%
lst = [deep_train, deep_test,]  
deep= pd.concat(lst)

# %%
deep.head()
# Out:
#                          uid  \
# 0  deepoffense_mr_t2_train_0
# 1  deepoffense_mr_t2_train_1
# 2  deepoffense_mr_t2_train_2
# 3  deepoffense_mr_t2_train_3
# 4  deepoffense_mr_t2_train_4
#
#                                                 text  label_yn
# 0  राम कदम वागण्यात नाही तर बोलण्यात चुकला  बीजेप...         1
# 1  हीच का तुमची शिवसेने चि शिकवण... आपली आई म्हणज...         1
# 2  हे वाचा गाढवांनो. आणि हे ही सांगा की तुमच्या म...         1
# 3         भक्त आंधळे असतात. मूर्खा ना काही कळत नाही.         1
# 4  १९६६ साली छत्रपती शिवाजी महाराज या जागतिक दर्ज...         1

# %%
deep.shape
# Out:
# (3125, 3)

# %%
deep.to_csv('deepoffense_mr_t2.csv', header=True, index=False)

# %% [markdown]
# # HASOC

# %%
deep_train = pd.DataFrame(pd.read_excel('mr_Hasoc2021_train.xlsx'))

# %%
deep_test = pd.DataFrame(pd.read_csv('hasoc2021_mr_test-blind-2021.csv'))

# %%
deep_test.head()
# Out:
#          text_id                                               text
# 0  hasoc_mr_1875  माणसाची सर्वात मोठी समस्या   इतिहासाचे दाखले द...
# 1  hasoc_mr_1876  मुद्दामहून थुकत बसला  ते पण दोस्तांना बोलवून म...
# 2  hasoc_mr_1877  तुझे नोटिफिकेशन ऑन केलेत परंतु नाव दिसलं का शि...
# 3  hasoc_mr_1878  पांडुरंग हरी  वासुदेव हरी  तु तुझ्या घरी  मी म...
# 4  hasoc_mr_1879  भेंचोद  जेव्हा कोरोना कोरोना चालू होतं तेव्हा ...

# %%
deep_train.head()
# Out:
#       text_id                                               text task_1
# 0  hasoc_mr_1  भारत 15 ऑगस्ट 1947 ला स्वतंत्र झाला आणि त्यानं...    NOT
# 1  hasoc_mr_2  स्वत ला हवा तसा बाइट किंवा प्रतिक्रिया घेण्यास...    NOT
# 2  hasoc_mr_3  5 व्या नंबरची अर्थव्यवस्था आहे भारताची जगात 20...    NOT
# 3  hasoc_mr_4      च्यायला म्हणजे दुबईचा फोन ही पुडीच निघाली की.    HOF
# 4  hasoc_mr_5  ह्याला खरंतर कधीच आत टाकला पाहिजे होता. पैसा आ...    HOF

# %%
deep_train.shape
# Out:
# (1874, 3)

# %%
deep_test.rename(columns = {'subtask_a':'label_yn','tweet':'text'}, inplace = True)
deep_train.rename(columns = {'subtask_a':'label_yn','tweet':'text'}, inplace = True)

# %%
for idx in range(len(deep_test)):
    deep_test.loc[idx,'uid'] = 'deepoffense_mr_t2_test_'+str(idx)

# %%
for idx in range(len(deep_train)):
    deep_train.loc[idx,'uid'] = 'deepoffense_mr_t2_train_'+str(idx)

# %%
deep_train.head()
# Out:
#                                                 text   label_yn subtask_b  \
# 0  राम कदम वागण्यात नाही तर बोलण्यात चुकला  बीजेप...  Offensive       TIN
# 1  हीच का तुमची शिवसेने चि शिकवण... आपली आई म्हणज...  Offensive       TIN
# 2  हे वाचा गाढवांनो. आणि हे ही सांगा की तुमच्या म...  Offensive       TIN
# 3         भक्त आंधळे असतात. मूर्खा ना काही कळत नाही.  Offensive       TIN
# 4  १९६६ साली छत्रपती शिवाजी महाराज या जागतिक दर्ज...  Offensive       TIN
#
#   subtask_c                        uid
# 0       GRP  deepoffense_mr_t2_train_0
# 1       GRP  deepoffense_mr_t2_train_1
# 2       GRP  deepoffense_mr_t2_train_2
# 3       GRP  deepoffense_mr_t2_train_3
# 4       GRP  deepoffense_mr_t2_train_4

# %%
deep_test.head()
# Out:
#                                                 text   label_yn subtask_b  \
# 0    मुद्दामहून थुकत बसला  ते पण दोस्तांना बोलवून...  Offensive       TIN
# 1   भेंचोद  जेव्हा कोरोना कोरोना चालू होतं तेव्हा...  Offensive       TIN
# 2   तुम्ही काय गोट्या खेळायला राज्य सरकार मध्ये आ...  Offensive       TIN
# 3   शिवसेनेने निवडणुकीत स्वतंत्र बाणा ठेवावा.दळभद...  Offensive       TIN
# 4   माझा हंटर चांगलाच घुसलाय आईच्या पुच्चीत तुझ्य...  Offensive       TIN
#
#   subtask_c                       uid
# 0       IND  deepoffense_mr_t2_test_0
# 1       OTH  deepoffense_mr_t2_test_1
# 2       OTH  deepoffense_mr_t2_test_2
# 3       GRP  deepoffense_mr_t2_test_3
# 4       IND  deepoffense_mr_t2_test_4

# %%
deep_test.label_yn.value_counts()
# Out:
# not offensive    420
# Offensive        206
# Name: label_yn, dtype: int64

# %%
deep_test.label_yn.replace('Offensive', 1,inplace=True)
deep_test.label_yn.replace('not offensive', 0,inplace=True)
deep_train.label_yn.replace('Offensive', 1,inplace=True)
deep_train.label_yn.replace('not offensive', 0,inplace=True)

# %%
first_column = deep_train.pop('uid')

deep_train.insert(0, 'uid', first_column)

# %%
first_column = deep_test.pop('uid')
  
deep_test.insert(0, 'uid', first_column)

# %%
deep_test.head()
# Out:
#                         uid  \
# 0  deepoffense_mr_t2_test_0
# 1  deepoffense_mr_t2_test_1
# 2  deepoffense_mr_t2_test_2
# 3  deepoffense_mr_t2_test_3
# 4  deepoffense_mr_t2_test_4
#
#                                                 text  label_yn subtask_b  \
# 0    मुद्दामहून थुकत बसला  ते पण दोस्तांना बोलवून...         1       TIN
# 1   भेंचोद  जेव्हा कोरोना कोरोना चालू होतं तेव्हा...         1       TIN
# 2   तुम्ही काय गोट्या खेळायला राज्य सरकार मध्ये आ...         1       TIN
# 3   शिवसेनेने निवडणुकीत स्वतंत्र बाणा ठेवावा.दळभद...         1       TIN
# 4   माझा हंटर चांगलाच घुसलाय आईच्या पुच्चीत तुझ्य...         1       TIN
#
#   subtask_c
# 0       IND
# 1       OTH
# 2       OTH
# 3       GRP
# 4       IND

# %%
deep_test = deep_test[['uid','text','label_yn']]
deep_train = deep_train[['uid','text','label_yn']]

# %%
deep_test
# Out:
#                             uid  \
# 0      deepoffense_mr_t2_test_0
# 1      deepoffense_mr_t2_test_1
# 2      deepoffense_mr_t2_test_2
# 3      deepoffense_mr_t2_test_3
# 4      deepoffense_mr_t2_test_4
# ..                          ...
# 621  deepoffense_mr_t2_test_621
# 622  deepoffense_mr_t2_test_622
# 623  deepoffense_mr_t2_test_623
# 624  deepoffense_mr_t2_test_624
# 625  deepoffense_mr_t2_test_625
#
#                                                   text  label_yn
# 0      मुद्दामहून थुकत बसला  ते पण दोस्तांना बोलवून...         1
# 1     भेंचोद  जेव्हा कोरोना कोरोना चालू होतं तेव्हा...         1
# 2     तुम्ही काय गोट्या खेळायला राज्य सरकार मध्ये आ...         1
# 3     शिवसेनेने निवडणुकीत स्वतंत्र बाणा ठेवावा.दळभद...         1
# 4     माझा हंटर चांगलाच घुसलाय आईच्या पुच्चीत तुझ्य...         1
# ..                                                 ...       ...
# 621   मिट्रो कोथरुड मध्ये टेस्टिंग सेंटर कुठे आहे ए...         0
# ...

# %%
deep_train
# Out:
#                                uid  \
# 0        deepoffense_mr_t2_train_0
# 1        deepoffense_mr_t2_train_1
# 2        deepoffense_mr_t2_train_2
# 3        deepoffense_mr_t2_train_3
# 4        deepoffense_mr_t2_train_4
# ...                            ...
# 2494  deepoffense_mr_t2_train_2494
# 2495  deepoffense_mr_t2_train_2495
# 2496  deepoffense_mr_t2_train_2496
# 2497  deepoffense_mr_t2_train_2497
# 2498  deepoffense_mr_t2_train_2498
#
#                                                    text  label_yn
# 0     राम कदम वागण्यात नाही तर बोलण्यात चुकला  बीजेप...         1
# 1     हीच का तुमची शिवसेने चि शिकवण... आपली आई म्हणज...         1
# 2     हे वाचा गाढवांनो. आणि हे ही सांगा की तुमच्या म...         1
# 3            भक्त आंधळे असतात. मूर्खा ना काही कळत नाही.         1
# 4     १९६६ साली छत्रपती शिवाजी महाराज या जागतिक दर्ज...         1
# ...                                                 ...       ...
# 2494   पण बरेच जण जन्मजात मंद   मूर्ख आणि अंधभक्त अस...         1
# ...

# %%
deep_train.to_csv('deepoffense_mr_t2_train.csv', header=True, index=False)
deep_test.to_csv('deepoffense_mr_t2_test.csv', header=True, index=False)

# %%
deep_train= pd.DataFrame(pd.read_csv('deepoffense_mr_t2_train.csv'))
deep_test = pd.DataFrame(pd.read_csv('deepoffense_mr_t2_test.csv'))

# %%
lst = [deep_train, deep_test,]  
deep= pd.concat(lst)

# %%
deep.head()
# Out:
#                          uid  \
# 0  deepoffense_mr_t2_train_0
# 1  deepoffense_mr_t2_train_1
# 2  deepoffense_mr_t2_train_2
# 3  deepoffense_mr_t2_train_3
# 4  deepoffense_mr_t2_train_4
#
#                                                 text  label_yn
# 0  राम कदम वागण्यात नाही तर बोलण्यात चुकला  बीजेप...         1
# 1  हीच का तुमची शिवसेने चि शिकवण... आपली आई म्हणज...         1
# 2  हे वाचा गाढवांनो. आणि हे ही सांगा की तुमच्या म...         1
# 3         भक्त आंधळे असतात. मूर्खा ना काही कळत नाही.         1
# 4  १९६६ साली छत्रपती शिवाजी महाराज या जागतिक दर्ज...         1

# %%
deep.shape
# Out:
# (3125, 3)

# %%
deep.to_csv('deepoffense_mr_t2.csv', header=True, index=False)
